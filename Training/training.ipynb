# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov26n.pt')

results = model.train(
    data = 'your_dataset.yaml',
    epochs = 50,
    imgsz = 512,
    workers = 4,
    device = 0,
    name = 'your model name'
)
